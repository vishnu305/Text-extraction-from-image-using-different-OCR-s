# %% [markdown]
# ## 0. Install and Import Dependencies

# %%
# Install pytorch
#https://pytorch.org/get-started/locally/
# Install easyocr 
# !pip install easyocr
# Out:
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.5.5.64
#     Uninstalling opencv-python-headless-4.5.5.64:
#       Successfully uninstalled opencv-python-headless-4.5.5.64
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\divve\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\divve\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\divve\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\divve\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\divve\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\divve\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\divve\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\divve\anaconda3\lib\site-packages)
# ...

# %%
import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np
from PIL import Image

# %% [markdown]
# ## 1. Read in images or video

# %%
# IMAGE_PATH = './sign.png'
IMAGE_PATH = 'surf.jpeg'
# img=Image.open(IMAGE_PATH)
# img = img.resize((256,3))
# img = np.array(img)
# cv2.imwrite('color_img.jpg', img)

# %%
reader = easyocr.Reader(['en'])
result = reader.readtext(IMAGE_PATH)
result
# Out:
# [([[18, 18], [293, 18], [293, 145], [18, 145]], 'SURF', 0.9843162298202515)]

# %% [markdown]
# ## 2. Draw Results

# %%
top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]
font = cv2.FONT_HERSHEY_SIMPLEX

# %%
img = cv2.imread(IMAGE_PATH)
img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),3)
img = cv2.putText(img,text,top_left, font, 0.5,(255,255,255),2,cv2.LINE_AA)
plt.imshow(img)
plt.show()

# %%
result2 = reader.readtext('vishnu digital signature.jpeg')
for i in result2:
    print(i[1])
# Out:
# DVishnu Sai Kumr

# %%
result3 = reader.readtext('prescription1.jpg')
for i in result3:
    print(i[1],end=" ")
# Out:
# Na.ac & 20 #Q Noj * 40 06 ~xac (50 BA Suej20 Aue #& Aulx iop KJe8e ~ 4

# %%
result4 = reader.readtext('prescription2.png')
for i in result4:
    print(i[1],end=" ")
# plt.figure(figsize = (18,12))
plt.imshow(cv2.imread("prescription2.png"))
# Out:
# Name Address; Ouandmbo Mat MaEa Age:_29 Sex M Date:_|Z_ 06 274 R Wmcx ) lz~-Un dburd Cap4z 1 cap Gx @t {e Auun Physician's Sig; (dea Lic No; +2269 PTR No 444Z+ 82 No Ceqmia 008' dar dan Gww

# %%
result4 = reader.readtext('prescription3.png')
for i in result4:
    print(i[1],end=" ")
# plt.figure(figsize = (18,12))
plt.imshow(cv2.imread("prescription3.png"))
# Out:
# Levoceh M #solomed Ylq Liveaeo @hbzoet  950
